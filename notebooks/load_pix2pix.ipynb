# %%
# try loading from HF
import PIL
import requests
import torch
from io import BytesIO

from diffusers import StableDiffusionInstructPix2PixPipeline


def download_image(url):
    response = requests.get(url)
    return PIL.Image.open(BytesIO(response.content)).convert("RGB")


img_url = "https://huggingface.co/datasets/diffusers/diffusers-images-docs/resolve/main/mountain.png"

image = download_image(img_url).resize((512, 512))

pipe = StableDiffusionInstructPix2PixPipeline.from_pretrained(
    "timbrooks/instruct-pix2pix", torch_dtype=torch.float16
)
pipe = pipe.to("mps")
# Out:
# Cannot initialize model with low cpu memory usage because `accelerate` was not found in the environment. Defaulting to `low_cpu_mem_usage=False`. It is strongly recommended to install `accelerate` for faster and less memory-intense model loading. You can do so with:
# ```
# pip install accelerate
# ```
# .
# Loading pipeline components...:  43%|████▎     | 3/7 [00:03<00:04,  1.03s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 19
#      15 img_url = "https://huggingface.co/datasets/diffusers/diffusers-images-docs/resolve/main/mountain.png"
#      17 image = download_image(img_url).resize((512, 512))
# ---> 19 pipe = StableDiffusionInstructPix2PixPipeline.from_pretrained(
#      20     "timbrooks/instruct-pix2pix", torch_dtype=torch.float16
#      21 )
#      22 pipe = pipe.to("mps")
#
# File ~/Documents/RiceMDS/ELEC542/project/.venv/lib/python3.12/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/Documents/RiceMDS/ELEC542/project/.venv/lib/python3.12/site-packages/diffusers/pipelines/pipeline_utils.py:896, in DiffusionPipeline.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#     893     loaded_sub_model = passed_class_obj[name]
#     894 else:
#     895     # load sub model
# --> 896     loaded_sub_model = load_sub_model(
#     897         library_name=library_name,
#     898         class_name=class_name,
#     899         importable_classes=importable_classes,
#     900         pipelines=pipelines,
#     901         is_pipeline_module=is_pipeline_module,
#     902         pipeline_class=pipeline_class,
#     903         torch_dtype=torch_dtype,
#     904         provider=provider,
#     905         sess_options=sess_options,
#     906         device_map=current_device_map,
#     907         max_memory=max_memory,
#     908         offload_folder=offload_folder,
#     909         offload_state_dict=offload_state_dict,
#     910         model_variants=model_variants,
#     911         name=name,
#     912         from_flax=from_flax,
#     913         variant=variant,
#     914         low_cpu_mem_usage=low_cpu_mem_usage,
#     915         cached_folder=cached_folder,
#     916         use_safetensors=use_safetensors,
#     917     )
#     918     logger.info(
#     919         f"Loaded {name} as {class_name} from `{name}` subfolder of {pretrained_model_name_or_path}."
#     920     )
#     922 init_kwargs[name] = loaded_sub_model  # UNet(...), # DiffusionSchedule(...)
#
# File ~/Documents/RiceMDS/ELEC542/project/.venv/lib/python3.12/site-packages/diffusers/pipelines/pipeline_loading_utils.py:704, in load_sub_model(library_name, class_name, importable_classes, pipelines, is_pipeline_module, pipeline_class, torch_dtype, provider, sess_options, device_map, max_memory, offload_folder, offload_state_dict, model_variants, name, from_flax, variant, low_cpu_mem_usage, cached_folder, use_safetensors)
#     702 # check if the module is in a subdirectory
#     703 if os.path.isdir(os.path.join(cached_folder, name)):
# --> 704     loaded_sub_model = load_method(os.path.join(cached_folder, name), **loading_kwargs)
#     705 else:
#     706     # else load from the root directory
#     707     loaded_sub_model = load_method(cached_folder, **loading_kwargs)
#
# File ~/Documents/RiceMDS/ELEC542/project/.venv/lib/python3.12/site-packages/transformers/modeling_utils.py:4225, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    4215     if dtype_orig is not None:
#    4216         torch.set_default_dtype(dtype_orig)
#    4218     (
#    4219         model,
#    4220         missing_keys,
#    4221         unexpected_keys,
#    4222         mismatched_keys,
#    4223         offload_index,
#    4224         error_msgs,
# -> 4225     ) = cls._load_pretrained_model(
#    4226         model,
#    4227         state_dict,
#    4228         loaded_state_dict_keys,  # XXX: rename?
#    4229         resolved_archive_file,
#    4230         pretrained_model_name_or_path,
#    4231         ignore_mismatched_sizes=ignore_mismatched_sizes,
#    4232         sharded_metadata=sharded_metadata,
#    4233         _fast_init=_fast_init,
#    4234         low_cpu_mem_usage=low_cpu_mem_usage,
#    4235         device_map=device_map,
#    4236         offload_folder=offload_folder,
#    4237         offload_state_dict=offload_state_dict,
#    4238         dtype=torch_dtype,
#    4239         hf_quantizer=hf_quantizer,
#    4240         keep_in_fp32_modules=keep_in_fp32_modules,
#    4241         gguf_path=gguf_path,
#    4242         weights_only=weights_only,
#    4243     )
#    4245 # make sure token embedding weights are still tied if needed
#    4246 model.tie_weights()
#
# File ~/Documents/RiceMDS/ELEC542/project/.venv/lib/python3.12/site-packages/transformers/modeling_utils.py:4663, in PreTrainedModel._load_pretrained_model(cls, model, state_dict, loaded_keys, resolved_archive_file, pretrained_model_name_or_path, ignore_mismatched_sizes, sharded_metadata, _fast_init, low_cpu_mem_usage, device_map, offload_folder, offload_state_dict, dtype, hf_quantizer, keep_in_fp32_modules, gguf_path, weights_only)
#    4658     else:
#    4659         # Sharded checkpoint or whole but low_cpu_mem_usage==True
#    4660         assign_to_params_buffers = check_support_param_buffer_assignment(
#    4661             model_to_load, state_dict, start_prefix
#    4662         )
# -> 4663         error_msgs = _load_state_dict_into_model(
#    4664             model_to_load, state_dict, start_prefix, assign_to_params_buffers
#    4665         )
#    4667 else:
#    4668     # This should always be a list but, just to be sure.
#    4669     if not isinstance(resolved_archive_file, list):
#
# File ~/Documents/RiceMDS/ELEC542/project/.venv/lib/python3.12/site-packages/transformers/modeling_utils.py:775, in _load_state_dict_into_model(model_to_load, state_dict, start_prefix, assign_to_params_buffers)
#     772         if child is not None:
#     773             load(child, state_dict, prefix + name + ".", assign_to_params_buffers)
# --> 775 load(model_to_load, state_dict, prefix=start_prefix, assign_to_params_buffers=assign_to_params_buffers)
#     776 # Delete `state_dict` so it could be collected by GC earlier. Note that `state_dict` is a copy of the argument, so
#     777 # it's safe to delete it.
#     778 del state_dict
#
# File ~/Documents/RiceMDS/ELEC542/project/.venv/lib/python3.12/site-packages/transformers/modeling_utils.py:773, in _load_state_dict_into_model.<locals>.load(module, state_dict, prefix, assign_to_params_buffers)
#     771 for name, child in module._modules.items():
#     772     if child is not None:
# --> 773         load(child, state_dict, prefix + name + ".", assign_to_params_buffers)
#
# File ~/Documents/RiceMDS/ELEC542/project/.venv/lib/python3.12/site-packages/transformers/modeling_utils.py:773, in _load_state_dict_into_model.<locals>.load(module, state_dict, prefix, assign_to_params_buffers)
#     771 for name, child in module._modules.items():
#     772     if child is not None:
# --> 773         load(child, state_dict, prefix + name + ".", assign_to_params_buffers)
#
#     [... skipping similar frames: _load_state_dict_into_model.<locals>.load at line 773 (4 times)]
#
# File ~/Documents/RiceMDS/ELEC542/project/.venv/lib/python3.12/site-packages/transformers/modeling_utils.py:773, in _load_state_dict_into_model.<locals>.load(module, state_dict, prefix, assign_to_params_buffers)
#     771 for name, child in module._modules.items():
#     772     if child is not None:
# --> 773         load(child, state_dict, prefix + name + ".", assign_to_params_buffers)
#
# File ~/Documents/RiceMDS/ELEC542/project/.venv/lib/python3.12/site-packages/transformers/modeling_utils.py:769, in _load_state_dict_into_model.<locals>.load(module, state_dict, prefix, assign_to_params_buffers)
#     767                     module._load_from_state_dict(*args)
#     768     else:
# --> 769         module._load_from_state_dict(*args)
#     771 for name, child in module._modules.items():
#     772     if child is not None:
#
# File ~/Documents/RiceMDS/ELEC542/project/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:2441, in Module._load_from_state_dict(self, state_dict, prefix, local_metadata, strict, missing_keys, unexpected_keys, error_msgs)
#    2439             setattr(self, name, input_param)
#    2440         else:
# -> 2441             param.copy_(input_param)
#    2442 except Exception as ex:
#    2443     action = "swapping" if use_swap_tensors else "copying"
#
# KeyboardInterrupt:
